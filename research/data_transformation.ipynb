# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\chait\\ui\\FirstProj_MLOPS'

# %%
#os.chdir("../");

# %%
import pandas as pd;
from pathlib import Path;

# %%
data = pd.read_csv("artifacts/data_ingestion/winequality-red.csv");

# %%
from dataclasses import dataclass

# %%
@dataclass
class DataTransformationConfig:
    root_dir:Path
    data_path: Path;

# %%
from src.datasci.constants import *
from src.datasci.utils.common import read_yaml, create_directories;

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH
    ):
        self.config = read_yaml(config_filepath);
        self.params = read_yaml(params_filepath);
        self.schema = read_yaml(schema_filepath);

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config = self.config.data_transformation
        create_directories([config.root_dir]);
        data_transformation_config = DataTransformationConfig(
            root_dir = config.root_dir,
            data_path = config.data_path
        );
        return data_transformation_config;

# %%
from src.datasci import logger
from sklearn.model_selection import train_test_split

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config;

    def train_test_splitting(self):
        data = pd.read_csv(self.config.data_path);

        train, test = train_test_split(data);
        train.to_csv(os.path.join(self.config.root_dir, "train.csv"), index=False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index = False)

        logger.info("Split data to train and test");
        logger.info(train.shape);
        logger.info(test.shape);

# %%
try:
    config = ConfigurationManager();
    data_transformation_config = config.get_data_transformation_config();
    data_transformation = DataTransformation(config=data_transformation_config);
    data_transformation.train_test_splitting();
except Exception as e:
    raise e;
# Out:
# [2026-08-30 20:00:02,499: INFO: common: yaml file: config\config.yaml loaded successful]
# [2026-08-30 20:00:02,502: INFO: common: yaml file: params.yaml loaded successful]
# [2026-08-30 20:00:02,507: INFO: common: yaml file: schema.yaml loaded successful]
# [2026-08-30 20:00:02,509: INFO: common: created directory at: artifacts]
# [2026-08-30 20:00:02,511: INFO: common: created directory at: artifacts/data_transformation]
# [2026-08-30 20:00:02,548: INFO: 159275454: Split data to train and test]
# [2026-08-30 20:00:02,549: INFO: 159275454: (1199, 12)]
# [2026-08-30 20:00:02,551: INFO: 159275454: (400, 12)]
